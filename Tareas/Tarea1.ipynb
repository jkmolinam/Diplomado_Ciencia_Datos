# %% [markdown]
# <a href="https://colab.research.google.com/github/jkmolinam/Diplomado_Ciencia_Datos/blob/main/Tareas/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lección 1: Aprendizaje supervisado**
# ![aprendizaje.png](data:image/png;base64,...)

# %% [markdown]
# ## **Autora: Julieth Katherine Molina Martínez**
#
# ### Estudiante Universidad Nacional de Colombia del curso de Inteligencia artificial 2023-I.
# ![estadistica-2022-2-2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Aprendizaje supervisado**
# El aprendizaje supervisado tiene como objetivo encontrar una función o aplicación medible
# $$\hat{f}_{n}: X → Y$$
# Calculada a partir de muestras de entrenamiento de la forma
# $$(X_{i}, Y_{i})$$
# para $i =1, \cdots , n$, de tal modo que la expresión $\hat{f}_{n}$ esta cercana a $Y$. Para ello, se asocia a los conjuntos $X, Y$ a las $\sigma$- álgebras $B(X), B(Y)$, tal que la medibilidad de las variables X, Y
# está bien definida.
#
#
# *   Regla de decisión: Es una función medible $f:X\rightarrow Y$
# *   Función de pérdida: Es una función medible $L: Y \times Y \rightarrow \mathbb{R}^{+} \cup 0$. La aplicación de la regla de decisión $f$ a algún $X$ se define como $L(Y, f(X))$

# %% [markdown]
# ### **Ejemplo:**
#
# *   Para el problema de regresión usual, utilizamos como función de pérdida a
#  $L(x,y)=(x-y)^{2}$ que se denomina pérdida cuadrática.
#
# *   Si el problema es de clasificación, utilizamos la función de pérdida 0-1 en donde se toma el valor 0 si la decisión es correcta y 1 si la decisión es incorrecta.

# %% [markdown]
# ## **Referencias**
#
# *   Calderón, S. (2022) Aprendizaje Estadístico. Notas de clase: Series de Tiempo.
